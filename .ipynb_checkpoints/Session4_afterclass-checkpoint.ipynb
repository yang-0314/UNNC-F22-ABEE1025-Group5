# %% [markdown]
# ## Practices
# ### P1:
# Write a function most_frequent_number, which takes a list of integers as the input, return the most frequent number in the list. If there is a draw, return the smaller value.
#
# For example, the most frequent number of [1, 4, 12, 53, 21, 11, 12, 21, 22, 2, 3, 4, 6, 11, 12, 4, 11] is 4.
#
# 1 only 1 time
# 4: 3 times
# 12: 3 times
# 52: 1 time
# 21: 2 times
# 11: 3 times
# 22: 1 time
# 2: 1 time
# 3: 1 time
# 6: 1 time

# %%
def most_frequent_number(int_list):
    res_dict = {} # key is the integer, the value is the appreance times, e.g. {4: 3} means
                    # 4 has appeared for 3 times
    current_most_frequency_number = None
    current_most_frequent_times = None
    #  [1, 4, 12, 53, 21, 11, 12, 21, 22, 2, 3, 4, 6, 11, 12, 4, 11]
    for this_item in int_list:
        print('=============this iteration=================')
        print(f'integer: {this_item}')
        if this_item in res_dict:    
            this_item_appreance_times = res_dict[this_item] # before
            this_item_appreance_times += 1
            res_dict[this_item] = this_item_appreance_times # after I met this integer again
            # test whether or not this item is the current most frequent number
            if current_most_frequency_number is None:
                current_most_frequency_number = this_item
                current_most_frequent_times = this_item_appreance_times
            else:
                if this_item_appreance_times > current_most_frequent_times:
                    # do result updating
                    current_most_frequent_times = this_item_appreance_times
                    current_most_frequency_number = this_item
                elif this_item_appreance_times == current_most_frequent_times:
                    # draw condition
                    if this_item <= current_most_frequency_number:
                        # do result updating
                        current_most_frequent_times = this_item_appreance_times
                        current_most_frequency_number = this_item
                    else:
                        pass
                else:
                    pass
        else:
            # this is the first time to encounter this item
            res_dict[this_item] = 1
            if current_most_frequency_number is None:
                current_most_frequency_number = this_item
                current_most_frequent_times = 1
            
        print(f'results after this iteration: {current_most_frequency_number}, {current_most_frequent_times}')
    return (current_most_frequency_number, current_most_frequent_times)

# %%
int_list = [1, 4, 12, 53, 21, 11, 12, 21, 22, 2, 3, 4, 6, 11, 12, 4, 11]
most_frequent_number(int_list)
# Out:
# =============this iteration=================
# integer: 1
# results after this iteration: 1, 1
# =============this iteration=================
# integer: 4
# results after this iteration: 1, 1
# =============this iteration=================
# integer: 12
# results after this iteration: 1, 1
# =============this iteration=================
# integer: 53
# results after this iteration: 1, 1
# =============this iteration=================
# integer: 21
# results after this iteration: 1, 1
# =============this iteration=================
# integer: 11
# results after this iteration: 1, 1
# =============this iteration=================
# integer: 12
# results after this iteration: 12, 2
# =============this iteration=================
# integer: 21
# results after this iteration: 12, 2
# =============this iteration=================
# integer: 22
# results after this iteration: 12, 2
# =============this iteration=================
# integer: 2
# results after this iteration: 12, 2
# ...

# %%
int_list = [1, 4, 12, 53, 21, 11, 12, 21, 22, 2, 3, 4, 6, 11, 12, 4, 11, 12]
most_frequent_number(int_list)
# Out:
# =============this iteration=================
# integer: 1
# results after this iteration: 1, 1
# =============this iteration=================
# integer: 4
# results after this iteration: 1, 1
# =============this iteration=================
# integer: 12
# results after this iteration: 1, 1
# =============this iteration=================
# integer: 53
# results after this iteration: 1, 1
# =============this iteration=================
# integer: 21
# results after this iteration: 1, 1
# =============this iteration=================
# integer: 11
# results after this iteration: 1, 1
# =============this iteration=================
# integer: 12
# results after this iteration: 12, 2
# =============this iteration=================
# integer: 21
# results after this iteration: 12, 2
# =============this iteration=================
# integer: 22
# results after this iteration: 12, 2
# =============this iteration=================
# integer: 2
# results after this iteration: 12, 2
# ...

# %% [markdown]
# ### P2:
# The locker problem: Suppose the sports center has 1000 lockers. Initially, all lockers are closed. This day is Wednesday. You feel bored because you have no classes. So you go the sports center, and do the followings:
# For every locker, you close each opened locker and open each closed locker;
# Then, for every second locker, you close each opened locker and open each closed locker;
# Then, for every third locker,  you close each opened locker and open each closed locker;
# ...
# You do this for 100 times.
# Question: how many lockers are closed finally?

# %% [markdown]
# ### P3:
# is_prime(n), return True if n is a prime number, return False if n is not a prime number

# %% [markdown]
# ### P4:
# The Sieve of Eratosthenes: find a list of prime numbers from 1 up to 1000

# %%
# Not efficient way
import sympy as sp
primes = []
import time
st = time.time()
for i in range(1, 100001):
    if sp.isprime(i):
        primes.append(i)
print(f'running time is {time.time() - st}')
# Out:
# running time is 0.12468290328979492

# %%
def sieve_of_Eratosthenes():
    res_list = []
    res_dict = {}
    for i in range(1, 100001):
        res_dict[i] = 0 # the key is the test I want to test
                        # 0 means I am not sure, I need to test this number
                        # 1 means I am very sure it is not a prime number, so skip it
    for i in range(1, 100001):
        sure_or_not = res_dict[i]
        if sure_or_not == 0:
            is_prime = sp.isprime(i)
            if is_prime:
                res_list.append(i)
                # e.g. i = 2, I need mark 2, 4, 6, 8.... to 1
                # e.g. i = 5, I need to mark 5, 10, 15, 20... to 1
                for j in range(i, 100001, i):
                    res_dict[j] = 1
    return res_list

# %%
st = time.time()
sieve_of_Eratosthenes()
print(f'running time is {time.time() - st}')
# Out:
# running time is 0.0952916145324707

# %% [markdown]
# Why it is not efficient?
#
# We already have some prior knowledge for prime numbers, for example, 1 is not prime number, and all multiples of a prime number are not prime numbers.
#
# The algorithm https://www.youtube.com/watch?v=RXMy4CQSKyM

# %%
3, 
6, 9, 12, 15

11
22, 33, 44, 55,

# %%
import sympy as sp

# %%
sp.isprime(4)
# Out:
# False

# %% [markdown]
# ## I/O

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\z2020054\Downloads

# %%
import pandas as pd
table_df = pd.read_csv('../../z2020054/Desktop/eplusout.csv')

# %%
table_df.shape
# Out:
# (96, 13)

# %%
# get one value
# by default, the first row in a csv file is the header
table_df.iloc[1, 1] # get the value at 2nd row and 2nd col
table_df.iloc[0, 1] # get the value at 1st row and 2nd col
# Out:
# -4.324999999999999

# %%
# get one col
col_oat = table_df['Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)']
type(col_oat)
col_oat_vals = col_oat.values
type(col_oat_vals)
col_oat_vals[-1]
col_oat_vals[0]
col_oat_vals[0: 10]
# Out:
# array([ -4.325,  -6.95 ,  -9.575, -12.2  , -12.075, -11.95 , -11.825,
#        -11.7  , -11.55 , -11.4  ])

# %%
col_iat = table_df['ZONE ONE:Zone Mean Air Temperature [C](TimeStep) ']
col_iat_vals = col_iat.values
print(col_iat_vals)
# Out:
# [ 9.8879838   9.7788711   9.63881296  9.47776771  9.33268868  9.21978835
#   9.13289703  9.06071073  8.99445168  8.93001613  8.86636484  8.80346906
#   8.74040333  8.67680218  8.61282502  8.54873949  8.48584427  8.42463348
#   8.36484619  8.30607963  8.24670819  8.18604525  8.1244048   8.06231589
#   8.00040099  7.93898109  7.87803868  7.81746939  7.75703825  7.71767312
#   7.7580806   7.8863331   8.07645425  8.31641774  8.58365371  8.86698184
#   8.99888144  9.26847267  9.47416027  9.93342495 10.35175883 10.76525701
#  11.15809815 11.50877736 11.81316465 12.08285428 12.29210786 12.40712878
#  12.4460604  12.42063216 12.37435418 12.33454542 12.29623596 12.25994285
#  12.22773611 12.19918338 12.17903407 12.16123249 12.13409973 12.08658056
#  12.01929501 11.92586598 11.82135589 11.71884966 11.61636861 11.5000636
#  11.38642195 11.290388   11.21204012 11.14531063 11.08445926 11.02613548
#  10.97203136 10.92398964 10.88085114 10.83957231 10.80110347 10.7660649
# ...

# %%
oat_iat_df = table_df[['Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)',
                       'ZONE ONE:Zone Mean Air Temperature [C](TimeStep) ']]
oat_iat_df
# Out:
#     Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)  \
# 0                                              -4.325
# 1                                              -6.950
# 2                                              -9.575
# 3                                             -12.200
# 4                                             -12.075
# ..                                                ...
# 91                                             -1.700
# 92                                             -1.700
# 93                                             -1.700
# 94                                             -1.700
# 95                                             -1.700
#
#     ZONE ONE:Zone Mean Air Temperature [C](TimeStep)
# 0                                            9.887984
# 1                                            9.778871
# 2                                            9.638813
# 3                                            9.477768
# ...

# %%
oat_iat_df['delta_T'] = oat_iat_df['Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)']\
                        - oat_iat_df['ZONE ONE:Zone Mean Air Temperature [C](TimeStep) ']
oat_iat_df['abs_delta_T'] = abs(oat_iat_df['delta_T'])
oat_iat_df
# Out:
# C:\Users\z2020054\AppData\Local\Temp\ipykernel_16084\1745252650.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oat_iat_df['delta_T'] = oat_iat_df['Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)']\
# C:\Users\z2020054\AppData\Local\Temp\ipykernel_16084\1745252650.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   oat_iat_df['abs_delta_T'] = abs(oat_iat_df['delta_T'])
#     Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)  \
# ...

# %%
min(oat_iat_df['delta_T'])
# Out:
# -21.677767708323103

# %%
max(oat_iat_df['delta_T'])
# Out:
# -11.457545866207424

# %%
oat_iat_df.loc[oat_iat_df['delta_T']>-20]
# Out:
#     Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)  \
# 0                                              -4.325
# 1                                              -6.950
# 2                                              -9.575
# 11                                            -11.100
# 12                                            -11.100
# ..                                                ...
# 91                                             -1.700
# 92                                             -1.700
# 93                                             -1.700
# 94                                             -1.700
# 95                                             -1.700
#
#     ZONE ONE:Zone Mean Air Temperature [C](TimeStep)     delta_T  abs_delta_T
# 0                                            9.887984 -14.212984    14.212984
# 1                                            9.778871 -16.728871    16.728871
# ...

# %%
oat_iat_df.loc[(oat_iat_df['delta_T']>-20) 
               & (oat_iat_df['abs_delta_T']<15)]
# Out:
#     Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)  \
# 0                                              -4.325
# 50                                             -2.475
# 51                                             -2.200
# 52                                             -1.925
# 53                                             -1.650
# 54                                             -1.375
# 55                                             -1.100
# 56                                             -1.100
# 57                                             -1.100
# 58                                             -1.100
# 59                                             -1.100
# 60                                             -1.100
# 61                                             -1.100
# 62                                             -1.100
# 63                                             -1.100
# 64                                             -1.100
# ...

# %%
# We have to define our own to_datetime function because EnergyPlus use 24:00:00 to represent 00:00:00
import datetime as dt
def eplus_to_datetime(date_str):
    if date_str[-8:-6] != '24':
        dt_obj = pd.to_datetime(date_str)
    else:
        date_str = date_str[0: -8] + '00' + date_str[-6:]
        dt_obj = pd.to_datetime(date_str) + dt.timedelta(days=1)
    return dt_obj

# %%
# before the time conversion
table_df = pd.read_csv('../../z2020054/Desktop/eplusout.csv')
table_df['Date/Time']
# Out:
# 0      01/01  00:15:00
# 1      01/01  00:30:00
# 2      01/01  00:45:00
# 3      01/01  01:00:00
# 4      01/01  01:15:00
#             ...
# 91     01/01  23:00:00
# 92     01/01  23:15:00
# 93     01/01  23:30:00
# 94     01/01  23:45:00
# 95     01/01  24:00:00
# Name: Date/Time, Length: 96, dtype: object

# %%
# time series process
table_df = pd.read_csv('../../z2020054/Desktop/eplusout.csv')
table_df['Date/Time'] = '2002 ' + table_df['Date/Time']
table_df['Date/Time'] = table_df['Date/Time'].apply(eplus_to_datetime)

# %%
table_df['Date/Time']
# Out:
# 0    2002-01-01 00:15:00
# 1    2002-01-01 00:30:00
# 2    2002-01-01 00:45:00
# 3    2002-01-01 01:00:00
# 4    2002-01-01 01:15:00
#              ...
# 91   2002-01-01 23:00:00
# 92   2002-01-01 23:15:00
# 93   2002-01-01 23:30:00
# 94   2002-01-01 23:45:00
# 95   2002-01-02 00:00:00
# Name: Date/Time, Length: 96, dtype: datetime64[ns]

# %%
table_df
# Out:
#              Date/Time  \
# 0  2002-01-01 00:15:00
# 1  2002-01-01 00:30:00
# 2  2002-01-01 00:45:00
# 3  2002-01-01 01:00:00
# 4  2002-01-01 01:15:00
# ..                 ...
# 91 2002-01-01 23:00:00
# 92 2002-01-01 23:15:00
# 93 2002-01-01 23:30:00
# 94 2002-01-01 23:45:00
# 95 2002-01-02 00:00:00
#
#     Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)  \
# 0                                              -4.325
# 1                                              -6.950
# 2                                              -9.575
# 3                                             -12.200
# 4                                             -12.075
# ..                                                ...
# 91                                             -1.700
# 92                                             -1.700
# 93                                             -1.700
# 94                                             -1.700
# 95                                             -1.700
#
# ...

# %%
table_df.loc[table_df['Date/Time'] == '2002-01-01 20:15']
# Out:
#              Date/Time  \
# 80 2002-01-01 20:15:00
#
#     Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)  \
# 80                                              -1.25
#
#     ZONE ONE:Zone Windows Total Transmitted Solar Radiation Rate [W](TimeStep)  \
# 80                                                0.0
#
#     ZN001:WALL001:Surface Outside Face Sunlit Fraction [](TimeStep)  \
# 80                                                0.0
#
#     ZN001:WALL001:Surface Outside Face Incident Solar Radiation Rate per Area [W/m2](TimeStep)  \
# 80                                                0.0
#
#     ZN001:WALL001:WIN001:Surface Outside Face Sunlit Fraction [](TimeStep)  \
# 80                                                0.0
#
#     ZN001:WALL001:WIN001:Surface Outside Face Incident Solar Radiation Rate per Area [W/m2](TimeStep)  \
# 80                                                0.0
#
# ...

# %%
table_df['Date/Time'].iloc[0]
# Out:
# Timestamp('2002-01-01 00:15:00')

# %%
table_df.loc[table_df['Date/Time'].dt.hour == 19]
# Out:
#              Date/Time  \
# 75 2002-01-01 19:00:00
# 76 2002-01-01 19:15:00
# 77 2002-01-01 19:30:00
# 78 2002-01-01 19:45:00
#
#     Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)  \
# 75                                             -2.200
# 76                                             -1.925
# 77                                             -1.650
# 78                                             -1.375
#
#     ZONE ONE:Zone Windows Total Transmitted Solar Radiation Rate [W](TimeStep)  \
# 75                                                0.0
# 76                                                0.0
# 77                                                0.0
# 78                                                0.0
#
#     ZN001:WALL001:Surface Outside Face Sunlit Fraction [](TimeStep)  \
# 75                                                0.0
# 76                                                0.0
# 77                                                0.0
# ...

# %%
table_df.loc[table_df['Date/Time'].dt.minute == 15]
# Out:
#              Date/Time  \
# 0  2002-01-01 00:15:00
# 4  2002-01-01 01:15:00
# 8  2002-01-01 02:15:00
# 12 2002-01-01 03:15:00
# 16 2002-01-01 04:15:00
# 20 2002-01-01 05:15:00
# 24 2002-01-01 06:15:00
# 28 2002-01-01 07:15:00
# 32 2002-01-01 08:15:00
# 36 2002-01-01 09:15:00
# 40 2002-01-01 10:15:00
# 44 2002-01-01 11:15:00
# 48 2002-01-01 12:15:00
# 52 2002-01-01 13:15:00
# 56 2002-01-01 14:15:00
# 60 2002-01-01 15:15:00
# 64 2002-01-01 16:15:00
# 68 2002-01-01 17:15:00
# 72 2002-01-01 18:15:00
# 76 2002-01-01 19:15:00
# 80 2002-01-01 20:15:00
# 84 2002-01-01 21:15:00
# 88 2002-01-01 22:15:00
# 92 2002-01-01 23:15:00
#
#     Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)  \
# 0                                              -4.325
# 4                                             -12.075
# 8                                             -11.550
# 12                                            -11.100
# 16                                            -10.975
# ...

# %%
table_df.loc[(table_df['Date/Time'].dt.minute == 15) 
            & (table_df['Date/Time'].dt.hour >= 8) 
            & (table_df['Date/Time'].dt.hour <= 12)]
# Out:
#              Date/Time  \
# 32 2002-01-01 08:15:00
# 36 2002-01-01 09:15:00
# 40 2002-01-01 10:15:00
# 44 2002-01-01 11:15:00
# 48 2002-01-01 12:15:00
#
#     Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)  \
# 32                                             -9.725
# 36                                             -8.350
# 40                                             -6.275
# 44                                             -4.575
# 48                                             -3.025
#
#     ZONE ONE:Zone Windows Total Transmitted Solar Radiation Rate [W](TimeStep)  \
# 32                                        2845.924519
# 36                                        5678.748794
# 40                                        7658.066376
# 44                                        7469.245614
# 48                                        4288.105065
#
#     ZN001:WALL001:Surface Outside Face Sunlit Fraction [](TimeStep)  \
# ...

# %%
table_df.loc[(table_df['Date/Time'].dt.hour == 4) & (table_df['Date/Time'].dt.minute == 15)]
# Out:
#              Date/Time  \
# 16 2002-01-01 04:15:00
#
#     Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)  \
# 16                                            -10.975
#
#     ZONE ONE:Zone Windows Total Transmitted Solar Radiation Rate [W](TimeStep)  \
# 16                                                0.0
#
#     ZN001:WALL001:Surface Outside Face Sunlit Fraction [](TimeStep)  \
# 16                                                0.0
#
#     ZN001:WALL001:Surface Outside Face Incident Solar Radiation Rate per Area [W/m2](TimeStep)  \
# 16                                                0.0
#
#     ZN001:WALL001:WIN001:Surface Outside Face Sunlit Fraction [](TimeStep)  \
# 16                                                0.0
#
#     ZN001:WALL001:WIN001:Surface Outside Face Incident Solar Radiation Rate per Area [W/m2](TimeStep)  \
# 16                                                0.0
#
# ...

# %%
table_df.loc[(table_df['Date/Time'].dt.hour == 4) & (table_df['Date/Time'].dt.minute == 15)]['Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)']
# Out:
# 16   -10.975
# Name: Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep), dtype: float64

# %%
table_df.loc[(table_df['Date/Time'].dt.hour == 23)
             & (table_df['Date/Time'].dt.minute == 15), 
             'Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)']
# Out:
# 92   -1.7
# Name: Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep), dtype: float64

# %%
# change a value
table_df.loc[(table_df['Date/Time'].dt.hour == 23)
             & (table_df['Date/Time'].dt.minute == 15), 
             'Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)'] \
                = -4.5
table_df
# Out:
#              Date/Time  \
# 0  2002-01-01 00:15:00
# 1  2002-01-01 00:30:00
# 2  2002-01-01 00:45:00
# 3  2002-01-01 01:00:00
# 4  2002-01-01 01:15:00
# ..                 ...
# 91 2002-01-01 23:00:00
# 92 2002-01-01 23:15:00
# 93 2002-01-01 23:30:00
# 94 2002-01-01 23:45:00
# 95 2002-01-02 00:00:00
#
#     Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)  \
# 0                                              -4.325
# 1                                              -6.950
# 2                                              -9.575
# 3                                             -12.200
# 4                                             -12.075
# ..                                                ...
# 91                                             -1.700
# 92                                             -4.500
# 93                                             -1.700
# 94                                             -1.700
# 95                                             -1.700
#
# ...

# %%
table_df['Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)']
# Out:
# 0     -4.325
# 1     -6.950
# 2     -9.575
# 3    -12.200
# 4    -12.075
#        ...
# 91    -1.700
# 92    -4.500
# 93    -1.700
# 94    -1.700
# 95    -1.700
# Name: Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep), Length: 96, dtype: float64

# %%
table_df['Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)'] =\
    [0 for i in range(96)]

# %%
table_df
# Out:
#              Date/Time  \
# 0  2002-01-01 00:15:00
# 1  2002-01-01 00:30:00
# 2  2002-01-01 00:45:00
# 3  2002-01-01 01:00:00
# 4  2002-01-01 01:15:00
# ..                 ...
# 91 2002-01-01 23:00:00
# 92 2002-01-01 23:15:00
# 93 2002-01-01 23:30:00
# 94 2002-01-01 23:45:00
# 95 2002-01-02 00:00:00
#
#     Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)  \
# 0                                                   0
# 1                                                   0
# 2                                                   0
# 3                                                   0
# 4                                                   0
# ..                                                ...
# 91                                                  0
# 92                                                  0
# 93                                                  0
# 94                                                  0
# 95                                                  0
#
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\z2020054\\Downloads'

# %%
# Write the table back to a file
table_df.to_csv('../Desktop/out2.csv')

# %%
table_df.columns
# Out:
# Index(['Date/Time',
#        'Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)',
#        'ZONE ONE:Zone Windows Total Transmitted Solar Radiation Rate [W](TimeStep)',
#        'ZN001:WALL001:Surface Outside Face Sunlit Fraction [](TimeStep)',
#        'ZN001:WALL001:Surface Outside Face Incident Solar Radiation Rate per Area [W/m2](TimeStep)',
#        'ZN001:WALL001:WIN001:Surface Outside Face Sunlit Fraction [](TimeStep)',
#        'ZN001:WALL001:WIN001:Surface Outside Face Incident Solar Radiation Rate per Area [W/m2](TimeStep)',
#        'ZN001:WALL001:WIN001:Surface Window Transmitted Solar Radiation Rate [W](TimeStep)',
#        'ZN001:WALL001:Surface Inside Face Temperature [C](TimeStep)',
#        'ZN001:WALL001:Surface Outside Face Temperature [C](TimeStep)',
#        'ZN001:WALL001:WIN001:Surface Inside Face Temperature [C](TimeStep)',
#        'ZN001:WALL001:WIN001:Surface Outside Face Temperature [C](TimeStep)',
# ...

# %% [markdown]
# ## Plot

# %%
import matplotlib.pyplot as plt
plt.plot(table_df['ZONE ONE:Zone Mean Air Temperature [C](TimeStep) '])

# %%
test_list = [1, 2, 3, 5, 7, 4, 3, 1]
plt.plot(test_list)

# %%
x_list = [1, 2, 4, 5, 6]
y_list = [2, 4, 5, 7, 9]
plt.plot(x_list)
plt.plot(y_list)

# %%
plt.scatter(x_list, y_list)

# %%
# Out:
# 0    2002-01-01 00:15:00
# 1    2002-01-01 00:30:00
# 2    2002-01-01 00:45:00
# 3    2002-01-01 01:00:00
# 4    2002-01-01 01:15:00
#              ...
# 91   2002-01-01 23:00:00
# 92   2002-01-01 23:15:00
# 93   2002-01-01 23:30:00
# 94   2002-01-01 23:45:00
# 95   2002-01-02 00:00:00
# Name: Date/Time, Length: 96, dtype: datetime64[ns]

# %%
import matplotlib.dates as mdates
data_st_date = table_df.iloc[0]['Date/Time']
data_ed_date = table_df.iloc[-1]['Date/Time']
fontsize = 35
fig, axs = plt.subplots(1, 1, figsize=(20,10))
date_list = table_df['Date/Time']
i = 0
iat_data = table_df['ZONE ONE:Zone Mean Air Temperature [C](TimeStep) '].values
axs.plot(date_list, iat_data, label = 'Zone Mean Air Temperature', linewidth=2,
        color = 'k')
datetime_ax_loc = mdates.HourLocator()  
datetime_ax_fmt = mdates.DateFormatter('%H:%M')
axs.xaxis.set_major_locator(datetime_ax_loc)
axs.xaxis.set_major_formatter(datetime_ax_fmt)
for tick in axs.xaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize*0.8) 
for tick in axs.yaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize*0.8) 
axs.tick_params('x', labelrotation=45)
axs.set_xlabel('Time (%s to %s)'%(data_st_date, data_ed_date),
              fontsize = fontsize)
axs.set_ylabel('Air Temperature (C)',
              fontsize = fontsize)
axs.yaxis.get_offset_text().set_fontsize(fontsize*0.7)
axs.legend(fontsize = fontsize)

# %%
plt.plot(table_df['ZONE ONE:Zone Mean Air Temperature [C](TimeStep) '])
plt.plot(table_df['Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)'])

# %%
data_st_date = table_df.iloc[0]['Date/Time']
data_ed_date = table_df.iloc[-1]['Date/Time']
fontsize = 20
fig, axs = plt.subplots(1, 1, figsize=(20,10))
date_list = table_df['Date/Time']
for item in ['ZONE ONE:Zone Mean Air Temperature [C](TimeStep) ','Environment:Site Outdoor Air Drybulb Temperature [C](TimeStep)']:
    this_y = table_df[item].values
    axs.plot(date_list, this_y,
            alpha = 0.7,
            linestyle = '--',
            linewidth = 2,
            label = item)
datetime_ax_loc = mdates.HourLocator()  
datetime_ax_fmt = mdates.DateFormatter('%H:%M')
axs.xaxis.set_major_locator(datetime_ax_loc)
axs.xaxis.set_major_formatter(datetime_ax_fmt)
for tick in axs.xaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize*0.8) 
for tick in axs.yaxis.get_major_ticks():
    tick.label.set_fontsize(fontsize*0.8) 
axs.tick_params('x', labelrotation=45)
axs.set_xlabel('Time (%s to %s)'%(data_st_date, data_ed_date),
              fontsize = fontsize)
axs.set_ylabel('Air Temperature (C)',
              fontsize = fontsize)
axs.legend(fontsize = fontsize)

# %% [markdown]
# ## JSON
# import, edit and save a JSON file

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\z2020054\\Downloads'

# %%
import json
 
# Opening JSON file
with open('1ZoneUncontrolled_win_test.epJSON') as epjson:
    epjson_dict = json.load(epjson)
epjson_dict
# Out:
# {'Building': {'Simple One Zone w Windows': {'loads_convergence_tolerance_value': 0.04,
#    'maximum_number_of_warmup_days': 30,
#    'minimum_number_of_warmup_days': 6,
#    'north_axis': 0,
#    'solar_distribution': 'MinimalShadowing',
#    'temperature_convergence_tolerance_value': 0.004,
#    'terrain': 'Suburbs'}},
#  'BuildingSurface:Detailed': {'Zn001:Flr001': {'construction_name': 'FLOOR',
#    'number_of_vertices': 4,
#    'outside_boundary_condition': 'Surface',
#    'outside_boundary_condition_object': 'Zn001:Flr001',
#    'sun_exposure': 'NoSun',
#    'surface_type': 'Floor',
#    'vertices': [{'vertex_x_coordinate': 15.24,
#      'vertex_y_coordinate': 0.0,
#      'vertex_z_coordinate': 0.0},
#     {'vertex_x_coordinate': 0.0,
#      'vertex_y_coordinate': 0.0,
#      'vertex_z_coordinate': 0.0},
#     {'vertex_x_coordinate': 0.0,
#      'vertex_y_coordinate': 15.24,
#      'vertex_z_coordinate': 0.0},
#     {'vertex_x_coordinate': 15.24,
# ...

# %%
epjson_dict['Building']['Simple One Zone w Windows']['loads_convergence_tolerance_value']
# Out:
# 0.04

# %%
epjson_dict["WindowMaterial:SimpleGlazingSystem"]['SimpleWindow:DOUBLE PANE WINDOW']['solar_heat_gain_coefficient']
# Out:
# 0.763

# %%
epjson_dict['WindowMaterial:SimpleGlazingSystem']['SimpleWindow:DOUBLE PANE WINDOW']['solar_heat_gain_coefficient'] = 0.88

# %%
epjson_dict["WindowMaterial:SimpleGlazingSystem"]['SimpleWindow:DOUBLE PANE WINDOW']['solar_heat_gain_coefficient']
# Out:
# 0.88

# %%
# I can access to some information
epjson_dict['WindowMaterial:SimpleGlazingSystem']
# Out:
# {'SimpleWindow:DOUBLE PANE WINDOW': {'solar_heat_gain_coefficient': 0.763,
#   'u_factor': 1.5,
#   'visible_transmittance': 0.812}}

# %%
# I can access a chain of information
epjson_dict['WindowMaterial:SimpleGlazingSystem']['SimpleWindow:DOUBLE PANE WINDOW']
# Out:
# {'solar_heat_gain_coefficient': 0.763,
#  'u_factor': 1.5,
#  'visible_transmittance': 0.812}

# %%
epjson_dict['WindowMaterial:SimpleGlazingSystem']['SimpleWindow:DOUBLE PANE WINDOW']['solar_heat_gain_coefficient']
# Out:
# 0.763

# %%
# I can change some information
epjson_dict['WindowMaterial:SimpleGlazingSystem']['SimpleWindow:DOUBLE PANE WINDOW']['solar_heat_gain_coefficient'] = 0.5
epjson_dict['WindowMaterial:SimpleGlazingSystem']
# Out:
# {'SimpleWindow:DOUBLE PANE WINDOW': {'solar_heat_gain_coefficient': 0.5,
#   'u_factor': 1.5,
#   'visible_transmittance': 0.812}}

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\z2020054\\Downloads'

# %%
# write JSON file back to file
with open('1ZoneUncontrolled_win_test_update1.epJSON', 'w') as epjson:
    json.dump(epjson_dict, epjson)

# %%
list_names = ['WindowMaterial:SimpleGlazingSystem', 'SimpleWindow:DOUBLE PANE WINDOW', 'solar_heat_gain_coefficient']

# %%
temp_dict = epjson_dict
for name in list_names[0: 2]:
    temp_dict = temp_dict[name]
    
temp_dict['solar_heat_gain_coefficient'] = 0.2

# %%
epjson_dict['WindowMaterial:SimpleGlazingSystem']
# Out:
# {'SimpleWindow:DOUBLE PANE WINDOW': {'solar_heat_gain_coefficient': 0.2,
#   'u_factor': 1.5,
#   'visible_transmittance': 0.812}}
